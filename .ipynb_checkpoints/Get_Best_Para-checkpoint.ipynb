# %%
import numpy as np
from matplotlib import cm, pyplot as plt
import matplotlib.dates as dates
import pandas as pd
from datetime import timedelta,date

import warnings
warnings.filterwarnings("ignore")

# %%
data_total_pd = pd.read_csv('data_total.csv',index_col =0)

# 修改索引为datetime格式
data_total_pd['date'] = np.array(data_total_pd.index)
data_total_pd['date'] = pd.to_datetime(data_total_pd['date'])
data_total_pd.set_index("date", inplace=True)

data_total_pd.fillna(0,inplace = True)



# 价格往后移5位
market_close_next = data_total_pd['price_raw'].shift(-5)
market_close_diff = market_close_next - data_total_pd['price_raw'] 

data_total_pd['price_next'] = market_close_next
data_total_pd['price_diff'] = market_close_diff


# 仓位的关键参数，初始值默认为1，每次循环要重新赋值
alpha = np.ones(data_total_pd.shape[0])
data_total_pd['alpha'] = alpha

# 评分，评分初始值默认为0，每次循环要重新赋值
score = np.zeros(data_total_pd.shape[0])
data_total_pd['score'] = score

# 评分，评分初始值默认为0，每次循环要重新赋值
score = np.zeros(data_total_pd.shape[0])
data_total_pd['market_yield'] = np.log(data_total_pd['price_next']/data_total_pd['price_raw'])


# 通过仓位调整后的收益率
data_total_pd['adjust_yield'] = np.zeros(data_total_pd.shape[0])

# %%
market_yield = np.cumsum(data_total_pd['market_yield'])

# 画图
market_yield.plot()

# %%
data_total_pd
# Out:
#             price_raw state  price_next  price_diff  alpha  score  \
# date
# 2015-01-05   3641.541    bb    3513.576    -127.965    1.0    0.0
# 2015-01-06   3641.059    bb    3514.040    -127.019    1.0    0.0
# 2015-01-07   3643.790    bb    3502.423    -141.367    1.0    0.0
# 2015-01-08   3559.259    bb    3604.121      44.862    1.0    0.0
# 2015-01-09   3546.723    bb    3635.146      88.423    1.0    0.0
# 2015-01-12   3513.576    bb    3355.155    -158.421    1.0    0.0
# 2015-01-13   3514.040    bb    3396.222    -117.818    1.0    0.0
# 2015-01-14   3502.423    bb    3548.885      46.462    1.0    0.0
# 2015-01-15   3604.121    bb    3567.613     -36.508    1.0    0.0
# 2015-01-16   3635.146    bb    3571.732     -63.414    1.0    0.0
# 2015-01-19   3355.155    bl    3607.985     252.830    1.0    0.0
# 2015-01-20   3396.222    bl    3574.931     178.709    1.0    0.0
# 2015-01-21   3548.885    bl    3525.323     -23.562    1.0    0.0
# 2015-01-22   3567.613    bl    3481.798     -85.815    1.0    0.0
# 2015-01-23   3571.732    bl    3434.390    -137.342    1.0    0.0
# 2015-01-26   3607.985    bl    3353.960    -254.025    1.0    0.0
# 2015-01-27   3574.931    bl    3437.445    -137.486    1.0    0.0
# 2015-01-28   3525.323    bl    3401.768    -123.555    1.0    0.0
# 2015-01-29   3481.798    bl    3366.946    -114.852    1.0    0.0
# 2015-01-30   3434.390    bl    3312.420    -121.970    1.0    0.0
# 2015-02-02   3353.960    bl    3345.921      -8.039    1.0    0.0
# 2015-02-03   3437.445    bl    3406.943     -30.502    1.0    0.0
# 2015-02-04   3401.768    bl    3434.124      32.356    1.0    0.0
# 2015-02-05   3366.946    bl    3442.874      75.928    1.0    0.0
# 2015-02-06   3312.420    bl    3469.828     157.408    1.0    0.0
# 2015-02-09   3345.921    bl    3499.483     153.562    1.0    0.0
# 2015-02-10   3406.943    bl    3522.322     115.379    1.0    0.0
# 2015-02-11   3434.124    bl    3478.729      44.605    1.0    0.0
# 2015-02-12   3442.874    bl    3566.295     123.421    1.0    0.0
# 2015-02-13   3469.828    bl    3572.843     103.015    1.0    0.0
# ...               ...   ...         ...         ...    ...    ...
# 2018-07-23   3525.750    ml    3515.080     -10.670    1.0    0.0
# 2018-07-24   3581.710    ml    3517.660     -64.050    1.0    0.0
# 2018-07-25   3577.750    mb    3447.390    -130.360    1.0    0.0
# 2018-07-26   3536.250    mb    3370.960    -165.290    1.0    0.0
# 2018-07-27   3521.230    mb    3315.280    -205.950    1.0    0.0
# 2018-07-30   3515.080    mb    3273.270    -241.810    1.0    0.0
# 2018-07-31   3517.660    mb    3368.870    -148.790    1.0    0.0
# 2018-08-01   3447.390    mb    3314.510    -132.880    1.0    0.0
# 2018-08-02   3370.960    mb    3397.530      26.570    1.0    0.0
# 2018-08-03   3315.280    mb    3405.020      89.740    1.0    0.0
# 2018-08-06   3273.270    ml    3390.340     117.070    1.0    0.0
# 2018-08-07   3368.870    ml    3372.910       4.040    1.0    0.0
# 2018-08-08   3314.510    ml    3291.980     -22.530    1.0    0.0
# 2018-08-09   3397.530    ml    3276.730    -120.800    1.0    0.0
# 2018-08-10   3405.020    ml    3229.620    -175.400    1.0    0.0
# 2018-08-13   3390.340    ml    3267.250    -123.090    1.0    0.0
# 2018-08-14   3372.910    ml    3326.650     -46.260    1.0    0.0
# 2018-08-15   3291.980    ml    3307.950      15.970    1.0    0.0
# 2018-08-16   3276.730    ml    3320.030      43.300    1.0    0.0
# 2018-08-17   3229.620    ml    3325.330      95.710    1.0    0.0
# 2018-08-20   3267.250    ml    3406.570     139.320    1.0    0.0
# 2018-08-21   3326.650    ml    3400.170      73.520    1.0    0.0
# 2018-08-22   3307.950    ml    3386.570      78.620    1.0    0.0
# 2018-08-23   3320.030    ml    3351.090      31.060    1.0    0.0
# 2018-08-24   3325.330    ml    3334.500       9.170    1.0    0.0
# 2018-08-27   3406.570    ml         NaN         NaN    1.0    0.0
# 2018-08-28   3400.170    ml         NaN         NaN    1.0    0.0
# 2018-08-29   3386.570    ml         NaN         NaN    1.0    0.0
# 2018-08-30   3351.090    ml         NaN         NaN    1.0    0.0
# 2018-08-31   3334.500    ml         NaN         NaN    1.0    0.0
#
#             market_yield  adjust_yield
# date
# 2015-01-05     -0.035773           0.0
# 2015-01-06     -0.035508           0.0
# 2015-01-07     -0.039569           0.0
# 2015-01-08      0.012526           0.0
# 2015-01-09      0.024625           0.0
# 2015-01-12     -0.046136           0.0
# 2015-01-13     -0.034103           0.0
# 2015-01-14      0.013178           0.0
# 2015-01-15     -0.010181           0.0
# 2015-01-16     -0.017599           0.0
# 2015-01-19      0.072651           0.0
# 2015-01-20      0.051282           0.0
# 2015-01-21     -0.006661           0.0
# 2015-01-22     -0.024348           0.0
# 2015-01-23     -0.039211           0.0
# 2015-01-26     -0.073008           0.0
# 2015-01-27     -0.039217           0.0
# 2015-01-28     -0.035677           0.0
# 2015-01-29     -0.033543           0.0
# 2015-01-30     -0.036160           0.0
# 2015-02-02     -0.002400           0.0
# 2015-02-03     -0.008913           0.0
# 2015-02-04      0.009467           0.0
# 2015-02-05      0.022300           0.0
# 2015-02-06      0.046426           0.0
# 2015-02-09      0.044873           0.0
# 2015-02-10      0.033305           0.0
# 2015-02-11      0.012905           0.0
# 2015-02-12      0.035221           0.0
# 2015-02-13      0.029257           0.0
# ...                  ...           ...
# 2018-07-23     -0.003031           0.0
# 2018-07-24     -0.018044           0.0
# 2018-07-25     -0.037117           0.0
# 2018-07-26     -0.047869           0.0
# 2018-07-27     -0.060268           0.0
# 2018-07-30     -0.071273           0.0
# 2018-07-31     -0.043219           0.0
# 2018-08-01     -0.039308           0.0
# 2018-08-02      0.007851           0.0
# 2018-08-03      0.026709           0.0
# 2018-08-06      0.035141           0.0
# 2018-08-07      0.001198           0.0
# 2018-08-08     -0.006821           0.0
# 2018-08-09     -0.036203           0.0
# 2018-08-10     -0.052886           0.0
# 2018-08-13     -0.036982           0.0
# 2018-08-14     -0.013810           0.0
# 2018-08-15      0.004839           0.0
# 2018-08-16      0.013128           0.0
# 2018-08-17      0.029204           0.0
# 2018-08-20      0.041757           0.0
# 2018-08-21      0.021860           0.0
# 2018-08-22      0.023489           0.0
# 2018-08-23      0.009312           0.0
# 2018-08-24      0.002754           0.0
# 2018-08-27           NaN           0.0
# 2018-08-28           NaN           0.0
# 2018-08-29           NaN           0.0
# 2018-08-30           NaN           0.0
# 2018-08-31           NaN           0.0
#
# [896 rows x 8 columns]

# %%
def cal_score(data_total_pd,n,score_BigBonus,score_BigLoss,score_MinorBonus,score_MinorLoss):
    # 每个日期进行循环比对
    date_operate = data_total_pd.index
    
    score_list = []
    for date_i in date_operate[:]:

        # 状态的pandas数组
        States_pd_current = data_total_pd[(data_total_pd.index <= date_i)&(data_total_pd.index > (date_i - timedelta(days = n)))]

        score_current = 0
        for index, row in States_pd_current.iterrows():
            if row['state'] == "bb":
                score_current += score_BigBonus
            elif row['state'] == "bl":
                score_current += score_BigLoss
            elif row['state'] == "mb":
                score_current += score_MinorBonus
            elif row['state'] == "ml":
                score_current += score_MinorLoss
        score_list.append(score_current)

    data_total_pd['score'] = np.array(score_list)
    return data_total_pd

# %%
# 上限总分值：100分
total_score = 5

# 开始循环，寻找合理参数
# 存储参数的数组
para_list = []
i = 0
for score_BigLoss in range(-5,3):
    for score_BigBonus in range(-2,6):
        for score_MinorLoss in range(-5,3):
            for score_MinorBonus in range(-2,6):
                for n_windows in range(1,21,2):

                    # 仓位的关键参数，初始值默认为1，每次循环要重新赋值
                    alpha = np.ones(data_total_pd.shape[0])
                    data_total_pd['alpha'] = alpha

                    # 评分，评分初始值默认为0，每次循环要重新赋值
                    score = np.zeros(data_total_pd.shape[0])
                    data_total_pd['score'] = score

                    # 通过仓位调整后的收益率，每次循环要重新赋值
                    data_total_pd['adjust_yield'] = np.zeros(data_total_pd.shape[0])

                    data_total_pd = cal_score(data_total_pd,n_windows,score_BigBonus,score_BigLoss,score_MinorBonus,score_MinorLoss)

                    data_total_pd['alpha'] = np.where(data_total_pd['score'] > 0,data_total_pd['score']/total_score,0)

                    
                    data_total_pd['adjust_yield'] =  \
                            np.log( 1 + data_total_pd['alpha'] * data_total_pd['price_diff'] / data_total_pd['price_raw'])

                    # 避免后续出错
                    data_total_pd.fillna(0,inplace = True)

                    # 计算胜率
                    win_rate = \
                        float(sum(data_total_pd['adjust_yield'] > data_total_pd['market_yield'])) / float(len(data_total_pd['adjust_yield']))

                    # print win_rate
                    # print sum(data_total_pd['adjust_yield'])
                    if sum(data_total_pd['adjust_yield']) > sum(data_total_pd['market_yield']):
                        if win_rate > 0.52:
                            para_list.append([n_windows,score_BigBonus,score_BigLoss,score_MinorBonus,score_MinorLoss,win_rate,sum(data_total_pd['adjust_yield'])])
                            # 提示                   
                            print "找到参数组：n为%d,score_BigBonus为%d,score_BigLoss为%d,score_MinorBonus为%d,score_MinorLoss为%d，胜率为%f，收益率为%f" \
                                    %(n_windows,score_BigBonus,score_BigLoss,score_MinorBonus,score_MinorLoss,win_rate,sum(data_total_pd['adjust_yield']))
# Out:
# 找到参数组：n为5,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为2,score_MinorLoss为-5，胜率为0.527902，收益率为0.590611
# 找到参数组：n为7,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为2,score_MinorLoss为-5，胜率为0.526786，收益率为0.783951
# 找到参数组：n为5,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为3,score_MinorLoss为-5，胜率为0.532366，收益率为0.796119
# 找到参数组：n为7,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为3,score_MinorLoss为-5，胜率为0.521205，收益率为1.017225
# 找到参数组：n为5,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为-5，胜率为0.530134，收益率为0.965390
# 找到参数组：n为7,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为-5，胜率为0.520089，收益率为1.214686
# 找到参数组：n为15,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为-5，胜率为0.520089，收益率为0.974548
# 找到参数组：n为5,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-5，胜率为0.525670，收益率为1.115069
# 找到参数组：n为7,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-5，胜率为0.520089，收益率为1.361959
# 找到参数组：n为13,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-5，胜率为0.525670，收益率为0.867684
# 找到参数组：n为19,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-5，胜率为0.520089，收益率为0.634956
# 找到参数组：n为5,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为2,score_MinorLoss为-4，胜率为0.527902，收益率为0.575420
# 找到参数组：n为7,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为2,score_MinorLoss为-4，胜率为0.526786，收益率为0.746777
# 找到参数组：n为5,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为3,score_MinorLoss为-4，胜率为0.530134，收益率为0.769417
# 找到参数组：n为7,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为3,score_MinorLoss为-4，胜率为0.521205，收益率为0.986209
# 找到参数组：n为5,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为-4，胜率为0.530134，收益率为0.941383
# 找到参数组：n为7,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为-4，胜率为0.520089，收益率为1.188660
# 找到参数组：n为15,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为-4，胜率为0.521205，收益率为0.838957
# 找到参数组：n为5,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-4，胜率为0.523438，收益率为1.059860
# 找到参数组：n为7,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-4，胜率为0.522321，收益率为1.335225
# 找到参数组：n为13,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-4，胜率为0.521205，收益率为0.674036
# 找到参数组：n为15,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-4，胜率为0.520089，收益率为0.464737
# 找到参数组：n为5,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为2,score_MinorLoss为-3，胜率为0.525670，收益率为0.545833
# 找到参数组：n为7,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为2,score_MinorLoss为-3，胜率为0.521205，收益率为0.709967
# 找到参数组：n为5,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为3,score_MinorLoss为-3，胜率为0.530134，收益率为0.745691
# 找到参数组：n为7,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为3,score_MinorLoss为-3，胜率为0.521205，收益率为0.961253
# 找到参数组：n为5,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为-3，胜率为0.529018，收益率为0.886464
# 找到参数组：n为7,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为-3，胜率为0.523438，收益率为1.163056
# 找到参数组：n为5,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-3，胜率为0.523438，收益率为0.994537
# 找到参数组：n为7,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-3，胜率为0.522321，收益率为1.289901
# 找到参数组：n为13,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-3，胜率为0.521205，收益率为0.492263
# 找到参数组：n为5,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为2,score_MinorLoss为-2，胜率为0.525670，收益率为0.522382
# 找到参数组：n为5,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为3,score_MinorLoss为-2，胜率为0.531250，收益率为0.691055
# 找到参数组：n为7,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为3,score_MinorLoss为-2，胜率为0.521205，收益率为0.936736
# 找到参数组：n为5,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为-2，胜率为0.525670，收益率为0.811685
# 找到参数组：n为7,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为-2，胜率为0.523438，收益率为1.100894
# 找到参数组：n为7,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-2，胜率为0.523438，收益率为1.207375
# 找到参数组：n为9,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-2，胜率为0.521205，收益率为0.992509
# 找到参数组：n为11,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-2，胜率为0.522321，收益率为0.204369
# 找到参数组：n为13,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-2，胜率为0.522321，收益率为0.315310
# 找到参数组：n为5,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为2,score_MinorLoss为-1，胜率为0.523438，收益率为0.458353
# 找到参数组：n为5,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为3,score_MinorLoss为-1，胜率为0.529018，收益率为0.611736
# 找到参数组：n为7,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为3,score_MinorLoss为-1，胜率为0.524554，收益率为0.857567
# 找到参数组：n为7,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为-1，胜率为0.522321，收益率为1.022665
# 找到参数组：n为9,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为-1，胜率为0.523438，收益率为0.907281
# 找到参数组：n为11,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为-1，胜率为0.521205，收益率为0.297217
# 找到参数组：n为13,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为-1，胜率为0.520089，收益率为0.450472
# 找到参数组：n为9,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-1，胜率为0.521205，收益率为0.862004
# 找到参数组：n为11,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-1，胜率为0.524554，收益率为0.037041
# 找到参数组：n为13,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-1，胜率为0.525670，收益率为0.151838
# 找到参数组：n为5,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为2,score_MinorLoss为0，胜率为0.525670，收益率为0.381124
# 找到参数组：n为7,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为2,score_MinorLoss为0，胜率为0.520089，收益率为0.577933
# 找到参数组：n为7,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为3,score_MinorLoss为0，胜率为0.520089，收益率为0.794010
# 找到参数组：n为9,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为0，胜率为0.521205，收益率为0.786645
# 找到参数组：n为11,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为0，胜率为0.521205，收益率为0.132366
# 找到参数组：n为5,score_BigBonus为-2,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为1，胜率为0.520089，收益率为0.601862
# 找到参数组：n为5,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为2,score_MinorLoss为-5，胜率为0.527902，收益率为0.583864
# 找到参数组：n为7,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为2,score_MinorLoss为-5，胜率为0.526786，收益率为0.780674
# 找到参数组：n为5,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为3,score_MinorLoss为-5，胜率为0.531250，收益率为0.785361
# 找到参数组：n为7,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为3,score_MinorLoss为-5，胜率为0.520089，收益率为1.003093
# 找到参数组：n为5,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为-5，胜率为0.527902，收益率为0.953806
# 找到参数组：n为5,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-5，胜率为0.524554，收益率为1.103537
# 找到参数组：n为13,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-5，胜率为0.524554，收益率为0.885419
# 找到参数组：n为19,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-5，胜率为0.520089，收益率为0.645582
# 找到参数组：n为5,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为2,score_MinorLoss为-4，胜率为0.527902，收益率为0.568674
# 找到参数组：n为7,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为2,score_MinorLoss为-4，胜率为0.526786，收益率为0.743501
# 找到参数组：n为5,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为3,score_MinorLoss为-4，胜率为0.529018，收益率为0.758659
# 找到参数组：n为7,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为3,score_MinorLoss为-4，胜率为0.520089，收益率为0.972077
# 找到参数组：n为5,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为-4，胜率为0.527902，收益率为0.929799
# 找到参数组：n为15,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为-4，胜率为0.520089，收益率为0.895300
# 找到参数组：n为5,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-4，胜率为0.522321，收益率为1.048328
# 找到参数组：n为7,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-4，胜率为0.521205，收益率为1.293853
# 找到参数组：n为13,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-4，胜率为0.520089，收益率为0.691770
# 找到参数组：n为5,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为2,score_MinorLoss为-3，胜率为0.525670，收益率为0.539086
# 找到参数组：n为7,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为2,score_MinorLoss为-3，胜率为0.521205，收益率为0.706690
# 找到参数组：n为5,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为3,score_MinorLoss为-3，胜率为0.529018，收益率为0.734933
# 找到参数组：n为7,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为3,score_MinorLoss为-3，胜率为0.520089，收益率为0.947120
# 找到参数组：n为5,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为-3，胜率为0.526786，收益率为0.874880
# 找到参数组：n为7,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为-3，胜率为0.521205，收益率为1.135086
# 找到参数组：n为5,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-3，胜率为0.522321，收益率为0.983005
# 找到参数组：n为7,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-3，胜率为0.521205，收益率为1.248529
# 找到参数组：n为13,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-3，胜率为0.520089，收益率为0.509997
# 找到参数组：n为5,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为2,score_MinorLoss为-2，胜率为0.525670，收益率为0.515636
# 找到参数组：n为5,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为3,score_MinorLoss为-2，胜率为0.530134，收益率为0.680297
# 找到参数组：n为7,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为3,score_MinorLoss为-2，胜率为0.520089，收益率为0.922603
# 找到参数组：n为5,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为-2，胜率为0.523438，收益率为0.800101
# 找到参数组：n为7,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为-2，胜率为0.521205，收益率为1.072924
# 找到参数组：n为7,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-2，胜率为0.522321，收益率为1.166003
# 找到参数组：n为9,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-2，胜率为0.520089，收益率为0.954918
# 找到参数组：n为11,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-2，胜率为0.521205，收益率为0.167388
# 找到参数组：n为13,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-2，胜率为0.521205，收益率为0.333045
# 找到参数组：n为5,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为2,score_MinorLoss为-1，胜率为0.523438，收益率为0.451606
# 找到参数组：n为5,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为3,score_MinorLoss为-1，胜率为0.527902，收益率为0.600978
# 找到参数组：n为7,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为3,score_MinorLoss为-1，胜率为0.523438，收益率为0.843435
# 找到参数组：n为7,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为-1，胜率为0.520089，收益率为0.994695
# 找到参数组：n为9,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为-1，胜率为0.523438，收益率为0.873661
# 找到参数组：n为11,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为-1，胜率为0.520089，收益率为0.267390
# 找到参数组：n为13,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为4,score_MinorLoss为-1，胜率为0.521205，收益率为0.460990
# 找到参数组：n为9,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-1，胜率为0.520089，收益率为0.824414
# 找到参数组：n为11,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-1，胜率为0.523438，收益率为0.000060
# 找到参数组：n为13,score_BigBonus为-1,score_BigLoss为-5,score_MinorBonus为5,score_MinorLoss为-1，胜率为0.524554，收益率为0.169572

# %%
para_pd = pd.DataFrame(para_list)
para_pd.columns = ["n_windows",'score_BigBonus','score_BigLoss','score_MinorBonus','score_MinorLoss','胜率','收益率']

para_pd.to_csv("best_para.csv")
